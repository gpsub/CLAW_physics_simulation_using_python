# %% [markdown]
# #Install Yolov5 and Pytorch

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd yolov5

import torch

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.9.0+cu111 _CudaDeviceProperties(name='NVIDIA GeForce GTX 1650', major=7, minor=5, total_memory=4096MB, multi_processor_count=16)

# %% [markdown]
# # Mount Google Drive

# %%
# Rename google drive to mydrive for easier access
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# 'Colab Notebooks'		   Models
#  Copy_of_DeepTest160-coco.zip	  'My Drive'
#  Copy_of_deepTest32_coco.zip	   oneFolder_pgan1.v1-v1.coco
# 'Copy of pgan1.v1-v1.coco.zip'	   oneFolder_pgan1.v1-v1.coco.zip
# 'Dani <> Jay Brainstorming.gdoc'   Other
#  Dataset			  'spd csv randoms.gsheet'
#  inference_results

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %%
# The /content directory represents the temporary storage of this current runtime. 
# Anything stored in /content WILL BE DELETED at the end of runtime
# %cd /content

# Unzip Dataset into the /content directory
# NOTE: change path according to your directory naming conventions and dataset name
# !unzip ./gdrive/MyDrive/Dataset/DeepTrash-Yolov5.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/18_jpg.rf.c47d177f9f2b825685ea184d852b3104.jpg
#  extracting: train/images/19_jpg.rf.0d0c95499d7ce7b30e65f4244bd44ff3.jpg
#  extracting: train/images/19_jpg.rf.73fcca7d74e670196de1cb79ab2eb975.jpg
#  extracting: train/images/19_jpg.rf.9da772e10e822f94e69c371d256c660d.jpg
#  extracting: train/images/1_jpg.rf.1d10b88ff8a267e47a2e6d987a92c922.jpg
#  extracting: train/images/1_jpg.rf.871d937782eb997e42750b67dd22aa8d.jpg
#  extracting: train/images/1_jpg.rf.cab525e3f0107c04877c2213988c7fdb.jpg
#  extracting: train/images/1_jpg.rf.faad99599460ac473d7e6edafb36cfd2.jpg
#  extracting: train/images/20_jpg.rf.17e620e55baa000183fe9abfc49d5509.jpg
#  extracting: train/images/20_jpg.rf.8964215c7ca97e21b9fc7b5a35fb6c66.jpg
#  extracting: train/images/20_jpg.rf.f528b93d04693c7c84b55c1632579218.jpg
#  extracting: train/images/21_png.rf.638cd7a49d30dbacaf762a422428133f.jpg
#  extracting: train/images/21_png_jpg.rf.6415e53aa644fe7246f83a297ce8d148.jpg
#  extracting: train/images/21_png_jpg.rf.d2a855a1c70e7c576248fbb00a55b5fb.jpg
#  extracting: train/images/22_jpg.rf.e7464377773e11d4c36af31847f9baf4.jpg
#  extracting: train/images/23_jpg.rf.328896aaaab3bc7363988ccd76f94bfe.jpg
#  extracting: train/images/23_jpg.rf.52d396e57364a15edfc1321f062fa0fd.jpg
#  extracting: train/images/24_jpg.rf.a0a0d57eee6f9dc23be73c2614be3d67.jpg
#  extracting: train/images/24_jpg.rf.a7f085bc4ca2a5a40c9e83a65aca8eef.jpg
#  extracting: train/images/25_jpg.rf.3ec282939ce6bff00900eec5b0924a80.jpg
#  extracting: train/images/25_jpg.rf.c2a67fa021340a7cb0f9d760c604b456.jpg
#  extracting: train/images/25_jpg.rf.cffe09b590419419db970a8cd6ab99c7.jpg
#  extracting: train/images/26_jpg.rf.5e0c7a1bed067504cd3553a248615023.jpg
#  extracting: train/images/26_jpg.rf.dd42d88abfc4e4d7c83d09dd040c5f90.jpg
#  extracting: train/images/27-copy-10_jpg.rf.efdbf19186cb8af202e98604cdcf0c4d.jpg
#  extracting: train/images/27-copy-10_jpg.rf.f11c92c2e9ff67198b960212d5cf5242.jpg
#  extracting: train/images/2_jpg.rf.0ced8d961ea4dde010677b86ca2ae8a3.jpg
#  extracting: train/images/2_jpg.rf.4fe7e8496a6c314b877944fa9e5ac012.jpg
#  extracting: train/images/2_jpg.rf.9ec6cd05ef7cd939fe934de8b82d536e.jpg
#  extracting: train/images/2_jpg.rf.c8f4ea6db119a47e01fc5629d1065b6b.jpg
#  extracting: train/images/2_jpg.rf.ca3f375c5d608727f7cf914dbc5c326b.jpg
#  extracting: train/images/3_jpg.rf.662eb15ae26a42c975664fdfd72c6e2e.jpg
#  extracting: train/images/3_jpg.rf.6c3fb0980dee5a275eabfa552751897a.jpg
#  extracting: train/images/3_jpg.rf.742e26dd6cc1bed5b3a68278402f9989.jpg
#  extracting: train/images/4_jpg.rf.4a5ac6d90004597afa82a7577e6e926d.jpg
#  extracting: train/images/4_jpg.rf.c2ec4feae4f1814d752a764dff14a21c.jpg
#  extracting: train/images/5_jpeg_jpg.rf.9e8d483ba1487ca0cd1013cd45167bdc.jpg
#  extracting: train/images/5_jpg.rf.25f491d37fc825cd13c159caa9e5d917.jpg
#  extracting: train/images/5_jpg.rf.b8ea0e3d56c6a6888921d54dcca63b25.jpg
#  extracting: train/images/6_jpeg.rf.8c50ba970600650760785a47076136d9.jpg
#  extracting: train/images/6_jpeg_jpg.rf.5d1305bca42f4ee75b17dd9eadd897ea.jpg
#  extracting: train/images/6_jpeg_jpg.rf.6dc2c052c4406d0f90c55472a734d7cb.jpg
#  extracting: train/images/6_jpg.rf.006a0790dabec1512e761a4a0dc53e53.jpg
#  extracting: train/images/6_jpg.rf.4579ee1bf4800dd416f38df6496822ab.jpg
#  extracting: train/images/7_jpg.rf.a68b6ab096b6fb18fec8c9e0e9c63fb1.jpg
#  extracting: train/images/7_jpg.rf.b3b99ba759492e7ab22614ec2181b1ca.jpg
#  extracting: train/images/7_jpg.rf.c78a1a4b84855ef6cdfea3beeee8f162.jpg
#  extracting: train/images/8_jpeg_jpg.rf.35eea3f74c46642831f2dca7a96b5ed7.jpg
#  extracting: train/images/8_jpg.rf.68b12e15db2a5cbf543316d3bbdd3d48.jpg
#  extracting: train/images/8_jpg.rf.a05b0a1d55ec2af928e47fe0f86a065d.jpg
#  extracting: train/images/9_jpg.rf.1c419f1e7bf9350678fb5f675e8f189a.jpg
#  extracting: train/images/9_jpg.rf.26e7168164bda1b3dcc3ef6e2d1c15b8.jpg
#  extracting: train/images/9_jpg.rf.6084b19d66afad664a219c4f6913bf27.jpg
#  extracting: train/images/9_jpg.rf.669472d2c44b9b60d65f3a3b93d3c26e.jpg
#  extracting: train/images/9_jpg.rf.f2951f6dc57c3b94882c301b42084f56.jpg
#  extracting: train/images/frame_00000_png.rf.1b33222b1c970d1ff7df1fd11b089077.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.0f7681a57012f674e28ac6a91d30dcfe.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.33fcf9d58032289ae29271435d9a4327.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.3944ab0cebd387b259f0d44d0a99505b.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.3fe91ee542f5db6842740b937e95855b.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.53416afe86e33ea2a76389b2fb5c7433.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.62b23fc5da78789ce302077c708eee45.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.72e91fdefe9e2707fd93814542f832b3.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.8d7130fd176f3a78c6d9e82adaff67a4.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.9a246fddd69b236814f7603705bf1a30.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.c1ed2fbdb534e55e8843bfd3a803e621.jpg
#  extracting: train/images/frame_00000_png_jpg.rf.ca47d94a07f808b81c14791afcdd1bde.jpg
#  extracting: train/images/frame_00010_png_jpg.rf.4cb1c554fd6b3413b0eaaf0b0b4cb9bd.jpg
#  extracting: train/images/frame_00010_png_jpg.rf.657bbd0d5ccc41ca941f27f0bebe88ce.jpg
#  extracting: train/images/frame_00015_png.rf.f3156b3ba789c828c892b63fb3df3da9.jpg
#  extracting: train/images/frame_00020_png_jpg.rf.0f5ff2af6e460eb7d59a21d981bc15ff.jpg
#  extracting: train/images/frame_00020_png_jpg.rf.ade40736f9b08df224462a05f8e68ead.jpg
#  extracting: train/images/frame_00025_png.rf.1851fe7f3e55340dad29180b3ce2fb8e.jpg
#  extracting: train/images/frame_00025_png.rf.d9c0e2b0f1685379f1c0ec5054eda217.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.0377c48587666d6287f8040a41ed8e65.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.1a95199d7497579777eb7a61b442fc5e.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.2e7352cd7c945366ca379604e9f5ea60.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.4494751a664965e1199e1775475710f8.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.4aa7a50bba82fed4b64b49462e15b3a2.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.74e6c16ee303d839330d9202a0ae7199.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.972fac662c1623321f6db43f28b85d1e.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.9736d2a3c545a47f19795512dc7715a3.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.b3c95a86ba6b72abfc037a18a8f73bc9.jpg
#  extracting: train/images/frame_00025_png_jpg.rf.d84c2b1cedb6997ffa81647252da8950.jpg
#  extracting: train/images/frame_00030_png.rf.7622628e5c15d4bc0f521a4b0d528e26.jpg
#  extracting: train/images/frame_00045_png.rf.f4e1478774ba484f71139c3d178f60ce.jpg
#  extracting: train/images/frame_00050_png.rf.021bfeda8a40487b251cb1c5d01298c4.jpg
#  extracting: train/images/frame_00050_png.rf.42d4207489f7d7896e59b8fd1f01cd11.jpg
#  extracting: train/images/frame_00050_png.rf.509a2109c4f1efabe862908cb9f4998f.jpg
#  extracting: train/images/frame_00050_png.rf.69399b9703a7e43d2a51d2c06cc9e6c0.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.3a4e8b7a8488a6ecb6f967f4db2445d5.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.49c32bf9d4562265acc0882d949302d8.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.5c613cea96f63973ef84a32246fc05bc.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.5ccba5f1368aaad215202832af4384d0.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.649ce3227cd1987b34d6788931762ff0.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.994e146a48c94b64b23d27b1e5038fbb.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.bb3bba0355e57370db8b0d455932f0ac.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.c5e3f283424a6893ef1cc6176446c047.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.c95a804d2084214db49ff03dd0696e95.jpg
#  extracting: train/images/frame_00050_png_jpg.rf.f468024f364dee4e23fa630824d7c27b.jpg
#  extracting: train/images/frame_00060_png.rf.42a611283478eeca7bf1b7ea127efd3b.jpg
#  extracting: train/images/frame_00060_png_jpg.rf.5b48b1f99f5ec48251f5c6670cb1bd26.jpg
#  extracting: train/images/frame_00060_png_jpg.rf.efe09b89b5eca0a13329e6fb90bee7af.jpg
#  extracting: train/images/frame_00075_png.rf.51e0489797c31fe95c2580efb86630bc.jpg
#  extracting: train/images/frame_00075_png.rf.94aa65f4f71a40852cbe896dea59be78.jpg
#  extracting: train/images/frame_00075_png.rf.fc04040e2ac6290f80f3661872dea891.jpg
#  extracting: train/images/frame_00075_png.rf.fffe83ecd85679233ac06fc36fff172a.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.068a59a2cc7943ae76b061b3ae3ff35f.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.10fdd8aa0a9117eaf182d7ee17cb48e1.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.2d3bd4c057e135633c09f6c0f1a751f7.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.6d2162cbafe560bf96e5658f945e7cd3.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.7d66678c3b3f6ae8472100d201f3f81a.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.9446f19a615869b4dc3c625485de3c70.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.dcf4519c557f7a9594e04191a7b3a8ca.jpg
#  extracting: train/images/frame_00075_png_jpg.rf.fcc61e1fb58418f53338cd65b6aa353a.jpg
#  extracting: train/images/frame_00080_png_jpg.rf.69488663a2540d260e10d1f105a38c1a.jpg
#  extracting: train/images/frame_00080_png_jpg.rf.8d52f04970b1b44aa7dafef3ea11a618.jpg
#  extracting: train/images/frame_00090_png.rf.a103a2d192e5a1cf677bb885a5fd659c.jpg
#  extracting: train/images/frame_00090_png.rf.a9e763c11783a981020ef8b49ed53653.jpg
#  extracting: train/images/frame_00090_png.rf.c6c4f97ef836d282a76d8c0089281e78.jpg
#  extracting: train/images/frame_00090_png_jpg.rf.48133ca132c8ff1113831dc33eada16c.jpg
#  extracting: train/images/frame_00090_png_jpg.rf.ebbee6b9892c144d8d60f5763d163b00.jpg
#  extracting: train/images/frame_00090_png_jpg.rf.f44ae1109b34e8e9c1ce303203d1583b.jpg
#  extracting: train/images/frame_00090_png_jpg.rf.f6156ba9c4a5a10bb42e576b93ee6310.jpg
#  extracting: train/images/frame_00100_png.rf.17564c0801fdba86d430eda8ddac1d69.jpg
#  extracting: train/images/frame_00100_png.rf.e75e630696bddef13a3b7a1583dead49.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.23f64a53d00d6d23e866e588a398ebbd.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.4385e4831a89ccfb199ccf50b0d6e9fa.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.6315749e98cfb1692172d9a9fd98a9a0.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.814a7e772038253a0538bdee06e64c9f.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.890841ecdf893bec6b41cb6cfd5f63bc.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.a00b7e979aa9f58ccbd7a7e6f707bf57.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.b8778147c17282267bb6407052b8cab2.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.cb9d4492119559c5ffa08ee34cd2e55f.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.d375785085f02b0390333934f9f960a6.jpg
#  extracting: train/images/frame_00100_png_jpg.rf.fe1ae7c7e3882c3b5f8042de2c08a853.jpg
#  extracting: train/images/frame_00105_png.rf.560996e4899c2d323782d6b175472da8.jpg
#  extracting: train/images/frame_00105_png_jpg.rf.145f3940100e68f2289540c7aa98740e.jpg
#  extracting: train/images/frame_00105_png_jpg.rf.6a4323cc7babfcb0d5e7bf80695ca2a2.jpg
#  extracting: train/images/frame_00105_png_jpg.rf.985dfa2f0cea74e5b2e0721632f3e846.jpg
#  extracting: train/images/frame_00110_png_jpg.rf.52fe2b417d85b2ed6711677b8e7aaa6c.jpg
#  extracting: train/images/frame_00120_png_jpg.rf.00fd11e766b74b7716aaf71f1b13353a.jpg
#  extracting: train/images/frame_00120_png_jpg.rf.b48609480931dd0a211b13e0f4e50a51.jpg
#  extracting: train/images/frame_00125_png.rf.06bab9e0655438fb96520e73bc943525.jpg
#  extracting: train/images/frame_00125_png.rf.472d3fd82296e2394884398f48de7f22.jpg
#  extracting: train/images/frame_00125_png.rf.543a3455500d4ba58e0222c39fc461dd.jpg
#  extracting: train/images/frame_00125_png.rf.b7239ac5f7664ca5ea4c1dea15d78465.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.4130d93151a06dfdaac53f33c68c1b6a.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.45af9a4d65b2f3d97f147d384f3d2104.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.4d6e1b2e3159712708723cb42e93530d.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.50cd61b9806ee2bf722e0d29152eadfa.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.5eb2efa74a167e8c396b0e87c7088e0d.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.d5a12e4301bfca2f7477779982c3fb74.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.e46c8dd1e96c5a3bb1fb27713f6c8948.jpg
#  extracting: train/images/frame_00125_png_jpg.rf.fd3ff87fab3ac6dfae1d3cb83dd33541.jpg
#  extracting: train/images/frame_00130_png_jpg.rf.4618fa3d8f9f309de482f2a112489e58.jpg
#  extracting: train/images/frame_00130_png_jpg.rf.d3915b064bf6ec27454cc1174d64db59.jpg
#  extracting: train/images/frame_00140_png_jpg.rf.bee2370033d0b69387aa1ad73f905f85.jpg
#  extracting: train/images/frame_00150_png.rf.40a52c0d109c5dd995d3b3df489b4035.jpg
#  extracting: train/images/frame_00150_png.rf.54c45ff82dd854793532b9c3cc525fa1.jpg
#  extracting: train/images/frame_00150_png.rf.55331d69bcb0b47cc88cd2c276e1f972.jpg
#  extracting: train/images/frame_00150_png.rf.909779710456e2db6cf6cc347f33d4d4.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.24f26e348c83ea07b83a54172ba1e2bb.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.2a855a810c5e411906be9fbad7232e28.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.3092e755e51b3672daf17aee79ac87e4.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.3890fe239cf6ea09f776ccb62b756221.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.409e0079a433c370352bb83b0b0a9d8c.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.4afe417d97c9ae3ff35740bd7c26346f.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.5c3f4cee225a2558bda82bb963df2a82.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.5faf746d3649231d6eff7839121e9df0.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.62e9b0f6e32240d3ec3b30c0f8923988.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.802e74c8bb7c56cfb2ea052dd3d0d65c.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.8af9063f435258c033fb312379b54eae.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.9c62fe9726c8d59f32d7526945e06854.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.bb00ba3917a4b4e48dc3974887ca7a4d.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.cf4af45c5be52840accbdb879d921920.jpg
#  extracting: train/images/frame_00150_png_jpg.rf.f8eb34d1eab86161ed29d53b9b436a71.jpg
#  extracting: train/images/frame_00160_png_jpg.rf.826019b0c09793a39faa7157d62556e9.jpg
#  extracting: train/images/frame_00170_png_jpg.rf.2524fcbc5117c99557b09ea583466250.jpg
#  extracting: train/images/frame_00170_png_jpg.rf.259892df82dc21f7134180a751ff0638.jpg
#  extracting: train/images/frame_00175_png.rf.100017a02b00b7ace76c5a539b32a7bd.jpg
#  extracting: train/images/frame_00175_png.rf.297c00720333ad01615a04014a3f0ca9.jpg
#  extracting: train/images/frame_00175_png.rf.66aee6c0953948b688f5fa03271a3dc5.jpg
#  extracting: train/images/frame_00175_png.rf.685437949976c54eb89fd9dec16101c6.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.0bd7601d86543b170e34dad56ecd8d5b.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.15f7639f7fe2520cc01ad4641f428f53.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.4dd7568709e052ea832a6462483a3853.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.7547e3103234aa7eb9ce16eac6d6a1e9.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.822261384fbccd5992a2dc7d683fc6a8.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.856ed76092c2ba0323e41bf5a65e64c8.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.96a40d22e27a56a99c69607fc295207c.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.c18563c4456255e531ccb8c38566712a.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.c9641b8ba5c390ef2bb9c8cb033cbe1a.jpg
#  extracting: train/images/frame_00175_png_jpg.rf.e59c0357e54792e98abced46cd06751d.jpg
#  extracting: train/images/frame_00180_png_jpg.rf.884561c4590d90a3bed14698fc5e0151.jpg
#  extracting: train/images/frame_00195_png_jpg.rf.de8a7c2136c63372c2fa4f279c43351c.jpg
#  extracting: train/images/frame_00200_png.rf.5ac81b8ecee314c689b0b0b7365b73de.jpg
#  extracting: train/images/frame_00200_png.rf.81a2218c064f1e0891cd781b3c93fd4c.jpg
#  extracting: train/images/frame_00200_png.rf.c60db7281403267979c3e409276cc92e.jpg
#  extracting: train/images/frame_00200_png.rf.fbdcc2b605e30e27b7c2417c6b89debb.jpg
#  extracting: train/images/frame_00200_png.rf.fdf6d082113f0a7b267f683b483abfd0.jpg
#  extracting: train/images/frame_00200_png_jpg.rf.26dde37dfb69fbb1d9e0a527e19a7877.jpg
#  extracting: train/images/frame_00315_png_jpg.rf.45591c375fa77649280c7c6902fea1cf.jpg
#  extracting: train/images/frame_00315_png_jpg.rf.5874413c870bed1102f0b86be83abfc1.jpg
#  extracting: train/images/frame_00315_png_jpg.rf.c3e25e11b578c31121cebc25f61a4b89.jpg
#  extracting: train/images/frame_00325_png.rf.15fef674e7d0bf0193b1214646923703.jpg
#  extracting: train/images/frame_00325_png_jpg.rf.4b1ca6c125b2c4f76a3b084cba1056e3.jpg
#  extracting: train/images/frame_00325_png_jpg.rf.753c611170132cb4082b0f1a67a1729f.jpg
#  extracting: train/images/frame_00325_png_jpg.rf.cb01d9a496720e57768da11bba8aab4a.jpg
#  extracting: train/images/frame_00325_png_jpg.rf.f1afa6b2f36a1161d7dbd86fca5a6991.jpg
#  extracting: train/images/frame_00330_png.rf.431235bb53651b1c29cdb1bfe1db8e64.jpg
#  extracting: train/images/frame_00330_png.rf.ac1546447f2c67f5f5f14042e85d6d4e.jpg
#  extracting: train/images/frame_00330_png.rf.e12c44e0ed23ded55e6a60213b0840d4.jpg
#  extracting: train/images/frame_00330_png_jpg.rf.b99df171099893e6f88b549b70692cbd.jpg
#  extracting: train/images/frame_00330_png_jpg.rf.bee0f7225c6cc240abfa5a38621291dc.jpg
#  extracting: train/images/frame_00330_png_jpg.rf.c53e3e5c4f36659a47822ab47d484e6e.jpg
#  extracting: train/images/frame_00330_png_jpg.rf.c7e370d4488647701a2ab30aa087af28.jpg
#  extracting: train/images/frame_00330_png_jpg.rf.fc4b71dbd136bb0a9b7e2cbd61eb0840.jpg
#  extracting: train/images/frame_00350_png_jpg.rf.2750ba3cef2648b24ec7d5ebd1bc1bd8.jpg
#  extracting: train/images/frame_00350_png_jpg.rf.3ced60b729743770170bafa9806b03e2.jpg
#  extracting: train/images/frame_00350_png_jpg.rf.46f1db9dff9102287f4473b2efda143c.jpg
#  extracting: train/images/frame_00350_png_jpg.rf.5c15a7817ec06440f0fdd7513afa9a99.jpg
#  extracting: train/images/frame_00350_png_jpg.rf.90797ef3bc07de029d9e4e1c23fe8fcb.jpg
#  extracting: train/images/frame_00350_png_jpg.rf.ac507e884604d25092b262f14a4f945f.jpg
#  extracting: train/images/frame_00350_png_jpg.rf.fb42fd30176e78309592faa2e9efb2b1.jpg
#  extracting: train/images/frame_00375_png.rf.026651a18dceb01691a7faff0d225164.jpg
#  extracting: train/images/frame_00375_png.rf.5e3223be8ca93ce743a03ff74d99c452.jpg
#  extracting: train/images/frame_00375_png.rf.78a0db0b3cc4a0cef39005b83bfc7829.jpg
#  extracting: train/images/frame_00375_png.rf.de1bee0d92d55fc4093470b67cd3cc8e.jpg
#  extracting: train/images/frame_00375_png_jpg.rf.005aeaed38842c5236e007a022aa155f.jpg
#  extracting: train/images/frame_00375_png_jpg.rf.1058988af137ee46cfc1a160a9d103e3.jpg
#  extracting: train/images/frame_00375_png_jpg.rf.12fc7fcbe60c3378893026da75687c69.jpg
#  extracting: train/images/frame_00375_png_jpg.rf.23f32b6085aa9654694b359f66994db5.jpg
#  extracting: train/images/frame_00525_png_jpg.rf.73d7fa107e0b5f11caf55a940723c854.jpg
#  extracting: train/images/frame_00525_png_jpg.rf.8753bbca80dcf01d681824520c946f48.jpg
#  extracting: train/images/frame_00525_png_jpg.rf.9b42d15241c82e7857dfe9a54c2da243.jpg
#  extracting: train/images/frame_00525_png_jpg.rf.bb3fdb5ec17c0db2e36744779654d7e4.jpg
#  extracting: train/images/frame_00525_png_jpg.rf.e3b55eeffdd45523a91861fc4c79db33.jpg
#  extracting: train/images/frame_00525_png_jpg.rf.f0830b90ca761d34e8c80abaad551cb4.jpg
#  extracting: train/images/frame_00525_png_jpg.rf.fa8bd4e20f9c169036b226f775c5583b.jpg
#  extracting: train/images/frame_00550_png.rf.394fcbb2ce79f31c098bd6ccdf4d0d1c.jpg
#  extracting: train/images/frame_00550_png.rf.6f746ebcf18051c2ddb9cf159c470022.jpg
#  extracting: train/images/frame_00550_png.rf.a07b6c04057e4ff0608c6c4b26df2b5d.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.0535ac50642c302f90b8f619467cdcaa.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.32736e944c15982d9bf65479d56f3f97.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.6a0ec7490dfb8361b80a001203233068.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.79d1c1baf7a16c5cc92dbe50ebd902d9.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.90f20f3a0545fa621320d9ca1e356abc.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.bc7373f5802c2950da19012ea1f13671.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.bd93204f63afa1b867b7ce70e4840e0e.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.e354b98597b3fb76a7f207958dd918f1.jpg
#  extracting: train/images/frame_00550_png_jpg.rf.f55cfe42a558ec1df90b39955171cddd.jpg
#  extracting: train/images/frame_00570_png.rf.684e5ecb38b636afec1c9f606e439d70.jpg
#  extracting: train/images/frame_00570_png_jpg.rf.335ebe1f85bc2c87328623f26f5a387a.jpg
#  extracting: train/images/frame_00575_png.rf.9c84dc3082f60e1d2b3fe7a102980987.jpg
#  extracting: train/images/frame_00575_png.rf.a305861708a773a61284f269d1ce9601.jpg
#  extracting: train/images/frame_00575_png.rf.e5b48877db2abefbce4943bc00059b81.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.0a84b3a943f557523252df10d7462dc3.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.2c12827e9468813e6b60b093727faf89.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.3c865afd40970a81e890748abb1ca8a2.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.5a7da9fb67623b15b62649e51fe7c84e.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.64beb2e32393755af251781b96d3021e.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.a0c20205a60ed040a927c6679cf19e8d.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.dda30e7cf595bbfaaf20681fe2e23a45.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.e153c7757986fe12b93ee38645753bde.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.e4c6123530b9defba843cacbe844bc96.jpg
#  extracting: train/images/frame_00575_png_jpg.rf.ee232fa0c6bd7bf0dc1783b17515d9ef.jpg
#  extracting: train/images/frame_00585_png.rf.51877fbdde17c905246fb204c9d3485c.jpg
#  extracting: train/images/frame_00585_png_jpg.rf.aef97d964d1369aefcb3fdfa05822032.jpg
#  extracting: train/images/frame_00600_png.rf.74c4ce6b6a0a4f195ff5a2912959ac1b.jpg
#  extracting: train/images/frame_00600_png.rf.84270a40f5f9732c79375b9652c35bf7.jpg
#  extracting: train/images/frame_00600_png.rf.aa0935fc5a9afb7de5461b4f7d09d322.jpg
#  extracting: train/images/frame_00600_png.rf.ea3ec46e78aa5b41f4d5684b38a551cd.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.1c041b219e00bf58a062dd8bcca4ec08.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.1fb8f1d9c229289455e65396875607b3.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.24e0e0f0fcd434eac9d5e952be98711a.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.35a7800f6ae0c5754aed5664be6a4d3b.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.783415816d548fd2fef5d04a109c1ef4.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.82833bd5344070f4ff52e165dd8ea4cd.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.975b65a1f3a86d02f7c4d8b681dcf769.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.ae8498a51917ff3faf64905fc3f12282.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.db3b9adc941896e106d4d28671b2468a.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.f1a414ec8a548d0213c870834cd36f33.jpg
#  extracting: train/images/frame_00600_png_jpg.rf.f7de97d4f8a0e8fb0a763759ceea07d7.jpg
#  extracting: train/images/frame_00615_png.rf.c7b75eaf2cfd9a3831b84badb5109dc9.jpg
#  extracting: train/images/frame_00615_png_jpg.rf.4a42af321b3fe1acb99e38fb2a9bff23.jpg
#  extracting: train/images/frame_00615_png_jpg.rf.f87afc8ae40a7cf1848b27d2ac6a7c99.jpg
#  extracting: train/images/frame_00625_png.rf.03ace1f3c33cfceb530286f01fd4850c.jpg
#  extracting: train/images/frame_00625_png.rf.5040ad66996bf67c5ea7a7317ee1c312.jpg
#  extracting: train/images/frame_00625_png.rf.6cffb28e050326f9b99fcb14b5ac031d.jpg
#  extracting: train/images/frame_00625_png.rf.801d3f6de6fbfdbbeef5488192163eee.jpg
#  extracting: train/images/frame_00625_png.rf.af7af205e58a6fa995fa737a0a149d2f.jpg
#  extracting: train/images/frame_00625_png_jpg.rf.043968b50023ea830c61c968c39c7abd.jpg
#  extracting: train/images/frame_00625_png_jpg.rf.0a0e5db8d952a64e7c7041bf2b6104ae.jpg
#  extracting: train/images/frame_00625_png_jpg.rf.860b6178eeea89c632d32add1fb7acaa.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.559e121b0943ed453c1223bc331416c7.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.584822dac23a8d7b6c9ebdde3cd0df02.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.637eec94a9b33edeb31bdfeb9782bc76.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.80842a63d5352dde3d492da2100509b3.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.8f8b48f0e5fd07744da706e616befb6a.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.94f60e698695fd3c8af9dd0cda190efb.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.a2047824f6020a75a733878bb263419a.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.b3fcdb39ac7781498a2169f1dbcc4234.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.c071b2b8bb4d6223520fc65c815be2ef.jpg
#  extracting: train/images/frame_00675_png_jpg.rf.e707eb01381e51b1ffce06713b1d2238.jpg
#  extracting: train/images/frame_00690_png.rf.3c7316694fb067f98090e81561af5317.jpg
#  extracting: train/images/frame_00690_png_jpg.rf.54dd1c334f265946a6df6916c1e7cb56.jpg
#  extracting: train/images/frame_00690_png_jpg.rf.a80463ed3d5bbd93e4e8e0e538303f3f.jpg
#  extracting: train/images/frame_00690_png_jpg.rf.d417e72ff71f18b7d40a457f897015c0.jpg
#  extracting: train/images/frame_00700_png.rf.4e8a0893e7d433ef0efdfac3d6f939a0.jpg
#  extracting: train/images/frame_00700_png.rf.993a4b167416dd7e89c5f3bbe84ea293.jpg
#  extracting: train/images/frame_00700_png_jpg.rf.437c63229e1b478a666791a83f2d6c75.jpg
#  extracting: train/images/frame_00700_png_jpg.rf.5eec6db7f4df33126fdf906d6386cdb3.jpg
#  extracting: train/images/frame_00700_png_jpg.rf.641282470f859f5f402bd4fcf9388a2c.jpg
#  extracting: train/images/frame_00700_png_jpg.rf.7730fb9465b809e7640ea11bcd7d9be4.jpg
#  extracting: train/images/frame_00700_png_jpg.rf.a0426f56e166de514ac38301ec601367.jpg
#  extracting: train/images/frame_00705_png.rf.36dddb8b541a509fc494dc594eab5ce4.jpg
#  extracting: train/images/frame_00705_png.rf.a67f8bd0d711d8f508334b82c65a46ad.jpg
#  extracting: train/images/frame_00705_png_jpg.rf.1be2c189b0d1782025548d682c1e093b.jpg
#  extracting: train/images/frame_00705_png_jpg.rf.49b9bec7b079692c81d913291871bb75.jpg
#  extracting: train/images/frame_00705_png_jpg.rf.6265fbeef890fedfb40d445d076c9efd.jpg
#  extracting: train/images/frame_00720_png_jpg.rf.036c99b02760916c4685e747700e604c.jpg
#  extracting: train/images/frame_00720_png_jpg.rf.7c149f09c02b0d10f96664e613af6f64.jpg
#  extracting: train/images/frame_00720_png_jpg.rf.b6504e7ed8f950e08adf119146ec05f6.jpg
#  extracting: train/images/frame_00725_png.rf.87ef8a1f974ce5024b77ba69c7b006ed.jpg
#  extracting: train/images/frame_00725_png.rf.8de9738425b5b94557438ba5d67d73ca.jpg
#  extracting: train/images/frame_00725_png.rf.b2596eb613b04a089e4e96b22ebdc827.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.00a72bfaa81e5b07d2405ed0896be021.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.0ec7fb78f33c80e6aaeef032241cd895.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.3949cc311409983c8cc73d8e48575a92.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.3c1071a1e5464e2c0ec7b1d2f56ce748.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.4b4a748b1c8ef9d39827d307b4bdcf6c.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.4b95bf225610fe4cacb06b56478624a5.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.9cf0ce5930b502351fad6242819f41d7.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.a00ea73df87be2fc3901ea05743b6dd4.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.a6cb27bc2bc9e1581ec9b34cef011844.jpg
#  extracting: train/images/frame_00725_png_jpg.rf.b0b935bd209b000f4b556b8f60bd71c1.jpg
#  extracting: train/images/frame_00735_png.rf.6e50b511787e742af8e9520b0691738b.jpg
#  extracting: train/images/frame_00735_png.rf.7205d75de344979aa48a1f15b334bc5e.jpg
#  extracting: train/images/frame_00735_png_jpg.rf.606c62fa82f475844cd7a72552b14fd2.jpg
#  extracting: train/images/frame_00735_png_jpg.rf.81f475ffb7b45a8f82fc930f1483102e.jpg
#  extracting: train/images/frame_00735_png_jpg.rf.860ef341d30942719324df9b09e30fb1.jpg
#  extracting: train/images/frame_00750_png.rf.2855e4cedebeb1388ca13e8a7f260c7c.jpg
#  extracting: train/images/frame_00750_png.rf.6508d9626a671778ae2d529bf3bbb99b.jpg
#  extracting: train/images/frame_00750_png.rf.b474949bacaea86c8e5a9e69e7c6d846.jpg
#  extracting: train/images/frame_00750_png.rf.cd89f788e7d029288d44dd9e7e01fbd0.jpg
#  extracting: train/images/frame_00750_png.rf.e19caa3b8e4a3da7ca5fc88d9be04ba7.jpg
#  extracting: train/images/frame_00750_png.rf.e1a170a0658121c1a2c28f5a83f56cc3.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.11e36d52895599407f447389fafa212a.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.274d73109f272940afae331097b08b18.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.2a1e256ec8d97a25300afbd7680a2cd3.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.2bd0f082736aa3a405adc36e4acc1650.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.3b374975c80d6a4cd0cbfa9812a86b5c.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.4e108e92872de0645b06d696fec48901.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.6442b5f54400271d10d27c592ff23fee.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.7e46d072db777a14ce4998922c01da8f.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.9601a1cf589de99f2db2c09773cbc552.jpg
#  extracting: train/images/frame_00750_png_jpg.rf.b5aea4a00a97633b9ca6387b6b4c6d11.jpg
#  extracting: train/images/frame_00765_png.rf.27b5a8bb2016f93ae62e8bced86cfa8d.jpg
#  extracting: train/images/frame_00765_png.rf.3c400f7331feaf6f9b8770f09ffd2c66.jpg
#  extracting: train/images/frame_00765_png_jpg.rf.01b1a37472d14e2d007f7f46e6e3697a.jpg
#  extracting: train/images/frame_00765_png_jpg.rf.ba06d3fd4a195ffae6461153feea56b3.jpg
#  extracting: train/images/frame_00765_png_jpg.rf.be018714b79d83bbb613909ede26c440.jpg
#  extracting: train/images/frame_00765_png_jpg.rf.f24ac6660b485a5b8023d6fb07082ca7.jpg
#  extracting: train/images/frame_00775_png.rf.2eb9aa7767e3a834bf48cda6a9c4d938.jpg
#  extracting: train/images/frame_00775_png.rf.4da0352db0746bc6ea8f1d212a4f2219.jpg
#  extracting: train/images/frame_00775_png.rf.9648b1881db711dc326823ea577c1ba3.jpg
#  extracting: train/images/frame_00775_png.rf.98eae7a5b8c1640aa082b8dce9c54daa.jpg
#  extracting: train/images/frame_00775_png.rf.e4ce537d7a76d7c36bc058ed4807f48f.jpg
#  extracting: train/images/frame_00775_png_jpg.rf.21584f3822fa739f2c502841ca421f84.jpg
#  extracting: train/images/frame_00775_png_jpg.rf.3594786c628432f1c7fb20138369a501.jpg
#  extracting: train/images/frame_00775_png_jpg.rf.40b18b686c05d6f3d97723dd0cb57b1b.jpg
#  extracting: train/images/frame_00775_png_jpg.rf.5f76822cbac1df1b90d07b3d238158ca.jpg
#  extracting: train/images/frame_00775_png_jpg.rf.6644f79a8227c7ac79c587908e5d28cf.jpg
#  extracting: train/images/frame_00775_png_jpg.rf.688d566617c85dddd180cf2de337442d.jpg
# ...
#  extracting: valid/labels/vid_000320_frame0000057_jpg.rf.6147f7c5a9a08e405e85d27b9e5aa9f9.txt
#  extracting: valid/labels/vid_000320_frame0000058_jpg.rf.718737bd3f75dd2cd97f16e8d6c77a8c.txt
#  extracting: valid/labels/vid_000320_frame0000059_jpg.rf.c72d48cbc2597b4e404a227607ab2449.txt
#  extracting: valid/labels/vid_000321_frame0000003_jpg.rf.02dbb5f75a740462a690ba011faccafb.txt
#  extracting: valid/labels/vid_000321_frame0000014_jpg.rf.0f85d48981c66c8516a951d22b8dc02d.txt
#  extracting: valid/labels/vid_000325_frame0000012_jpg.rf.21cf9a772dabf32c79f852116d695ebe.txt
#  extracting: valid/labels/vid_000325_frame0000019_jpg.rf.02677dcbd392492ec47a38ec5ecf1365.txt
#  extracting: valid/labels/vid_000325_frame0000025_jpg.rf.6c7fea5fa074538ce26ffdf01caa629f.txt
#  extracting: valid/labels/vid_000325_frame0000034_jpg.rf.ddabd34e47a7ead83e87b4cd12393f2a.txt
#  extracting: valid/labels/vid_000325_frame0000043_jpg.rf.29ebea961f36299ba76ab3196ffcace8.txt
#  extracting: valid/labels/vid_000325_frame0000060_jpg.rf.114d428216623049b5806651206d7678.txt
#  extracting: valid/labels/vid_000326_frame0000006_jpg.rf.2aba3abb54ada5218af32dd979078a69.txt
#  extracting: valid/labels/vid_000326_frame0000008_jpg.rf.e2bce320a1d942cc5a274b732955ce7f.txt
#  extracting: valid/labels/vid_000326_frame0000010_jpg.rf.e8c4628431b6ca3499329a9d8663a534.txt
#  extracting: valid/labels/vid_000326_frame0000013_jpg.rf.e1a3ddf8c90b2ff70589c7fefd93586f.txt
#  extracting: valid/labels/vid_000326_frame0000022_jpg.rf.4030ce0dfa7750954161a8eaad2805eb.txt
#  extracting: valid/labels/vid_000329_frame0000001_jpg.rf.75dda214e007ca4e3b07eca396383fb1.txt
#  extracting: valid/labels/vid_000329_frame0000016_jpg.rf.0ec561c2f4cec7df6a6b1c5408d9fc94.txt
#  extracting: valid/labels/vid_000331_frame0000179_jpg.rf.43a778892bc7cd6a152302e9e58b4266.txt
#  extracting: valid/labels/vid_000331_frame0000180_jpg.rf.8d735988a867ad9207428132af5f2351.txt
#  extracting: valid/labels/vid_000331_frame0000181_jpg.rf.73500407477fd52209be911addfd211b.txt
#  extracting: valid/labels/vid_000331_frame0000182_jpg.rf.6b43c9f81b7947a1fad840b4d77cd956.txt
#  extracting: valid/labels/vid_000331_frame0000183_jpg.rf.09f3db56ddaf4cf5d233a6364f469da2.txt
#  extracting: valid/labels/vid_000331_frame0000184_jpg.rf.094d13486a2a15da73a3e33c17e138db.txt
#  extracting: valid/labels/vid_000331_frame0000185_jpg.rf.0100ef9b08afad421a4b0fafcb2214fd.txt
#  extracting: valid/labels/vid_000331_frame0000187_jpg.rf.94f6275a07a7ffffac47ec0bff14e3b5.txt
#  extracting: valid/labels/vid_000331_frame0000188_jpg.rf.1245e0683b3fed6472773a6f8c58b886.txt
#  extracting: valid/labels/vid_000331_frame0000189_jpg.rf.0519e2d37627ea774f6ae819f0f73c31.txt
#  extracting: valid/labels/vid_000331_frame0000190_jpg.rf.5c3a2d9c2baa05a26933b05ef1cba6a5.txt
#  extracting: valid/labels/vid_000331_frame0000191_jpg.rf.956b4dfad222cad72bd93d6da675a050.txt
#  extracting: valid/labels/vid_000331_frame0000192_jpg.rf.376b5c7ddc38193bf5e29576c453e478.txt
#  extracting: valid/labels/vid_000331_frame0000193_jpg.rf.81a1360e722b5134e7bd12e65effb985.txt
#  extracting: valid/labels/vid_000331_frame0000194_jpg.rf.1c7e5096999f25b21bbcfbcb143534fc.txt
#  extracting: valid/labels/vid_000331_frame0000195_jpg.rf.ecea237d073e1a0a2d2c0914d70e104e.txt
#  extracting: valid/labels/vid_000331_frame0000197_jpg.rf.84ec1c319a2a5192a97ba9be7b80d1e2.txt
#  extracting: valid/labels/vid_000331_frame0000198_jpg.rf.e5dc8f319d12b6a70d2f0e5915ed5c94.txt
#  extracting: valid/labels/vid_000331_frame0000199_jpg.rf.45bddcf43facc036b8b8401e74d10a75.txt
#  extracting: valid/labels/vid_000331_frame0000200_jpg.rf.2c72934f8572778734d74174c104e22a.txt
#  extracting: valid/labels/vid_000331_frame0000201_jpg.rf.cc12ebb36f11ccf1f28f69d7414d045d.txt
#  extracting: valid/labels/vid_000331_frame0000202_jpg.rf.9bf4078db7611e8aa4134c0aaa0bf554.txt
#  extracting: valid/labels/vid_000331_frame0000203_jpg.rf.ea251c7b3f5387b696dd108998f766da.txt
#  extracting: valid/labels/vid_000331_frame0000204_jpg.rf.cb857a75e9a8a441ed3e2df783b443ea.txt
#  extracting: valid/labels/vid_000331_frame0000205_jpg.rf.fd2a91ae844d2cfc0274308e56f70373.txt
#  extracting: valid/labels/vid_000331_frame0000206_jpg.rf.6c779d6b38c98d3e5605ad9e8ae4c861.txt
#  extracting: valid/labels/vid_000331_frame0000207_jpg.rf.239e016bf7cbc5902bb7097fc4141a8c.txt
#  extracting: valid/labels/vid_000331_frame0000208_jpg.rf.b0a93af2a51a64857136ab07d2cc905c.txt
#  extracting: valid/labels/vid_000331_frame0000209_jpg.rf.735e6fd5733048319703faeb138f5eb5.txt
#  extracting: valid/labels/vid_000331_frame0000210_jpg.rf.d2ae3288a533058e681bd43f644d32d3.txt
#  extracting: valid/labels/vid_000331_frame0000212_jpg.rf.3eff51be3905e4cb305f1dbd2668bfbe.txt
#  extracting: valid/labels/vid_000331_frame0000213_jpg.rf.0aec0bed67bba3390412c30fa382c1ab.txt
#  extracting: valid/labels/vid_000331_frame0000248_jpg.rf.08356eb364b188f5669f07cc949463d3.txt
#  extracting: valid/labels/vid_000331_frame0000281_jpg.rf.0f00dc4ff091695e05a1f63536f08667.txt
#  extracting: valid/labels/vid_000331_frame0000282_jpg.rf.7b9dee229ed84feac844b8ce1724833d.txt
#  extracting: valid/labels/vid_000331_frame0000283_jpg.rf.bd5d7c76394a8b9d41726ebbec1683c6.txt
#  extracting: valid/labels/vid_000331_frame0000284_jpg.rf.57bb82e819a5b6cf986257fcbdcf6541.txt
#  extracting: valid/labels/vid_000331_frame0000285_jpg.rf.6fc9be17212289c6057ac134a743d986.txt
#  extracting: valid/labels/vid_000331_frame0000286_jpg.rf.2a8259de9b21b63eaef0e5824bd72164.txt
#  extracting: valid/labels/vid_000331_frame0000287_jpg.rf.3f1655986700d549bf8e47b918e0f246.txt
#  extracting: valid/labels/vid_000331_frame0000288_jpg.rf.37c06d39ca7eacfb2757cb740bf72659.txt
#  extracting: valid/labels/vid_000332_frame0000058_jpg.rf.0386b010aef64da55471115b9cde90c5.txt
#  extracting: valid/labels/vid_000332_frame0000059_jpg.rf.2725324e800bfda2d6c72191be257b74.txt
#  extracting: valid/labels/vid_000332_frame0000062_jpg.rf.6042796beeb263db27d14832c7d42d36.txt
#  extracting: valid/labels/vid_000332_frame0000063_jpg.rf.6f2ac0789d6e43f4be7bcbc8ef54088d.txt
#  extracting: valid/labels/vid_000332_frame0000066_jpg.rf.3e8d460b631198fc0437f444ea547369.txt
#  extracting: valid/labels/vid_000332_frame0000069_jpg.rf.fa1343d7c981fb724389ca8b90a1be14.txt
#  extracting: valid/labels/vid_000332_frame0000072_jpg.rf.de747d220b20f859c699f4bb4d2ba012.txt
#  extracting: valid/labels/vid_000332_frame0000083_jpg.rf.f9015e2e06115bed5a9f20008b322f1c.txt
#  extracting: valid/labels/vid_000332_frame0000085_jpg.rf.7b862bec118fafc8faf160b6b7bd5822.txt
#  extracting: valid/labels/vid_000332_frame0000088_jpg.rf.7d34565211e75718a8d91826361ffb80.txt
#  extracting: valid/labels/vid_000332_frame0000089_jpg.rf.ae559e5ae0b9de1551e29fd0809a7cfa.txt
#  extracting: valid/labels/vid_000332_frame0000090_jpg.rf.586f599246d83c86aef9c282aa6d347b.txt
#  extracting: valid/labels/vid_000332_frame0000092_jpg.rf.d2e6052b5c6829456880c5eb86457f0d.txt
#  extracting: valid/labels/vid_000332_frame0000093_jpg.rf.84951cc803f0b8704b08aa9d43892cb0.txt
#  extracting: valid/labels/vid_000332_frame0000095_jpg.rf.dac7fbff29c4c891569d953c71df239e.txt
#  extracting: valid/labels/vid_000332_frame0000097_jpg.rf.29ca0bd73cccd092f170e0e2ef78343e.txt
#  extracting: valid/labels/vid_000332_frame0000098_jpg.rf.cadd7ffeb9807cf581d82508687f252c.txt
#  extracting: valid/labels/vid_000332_frame0000101_jpg.rf.9a2f95f1ae54eb70de9590d6e975cc96.txt
#  extracting: valid/labels/vid_000332_frame0000102_jpg.rf.9afcd39fd03b742ffda1dca43cad0a0d.txt
#  extracting: valid/labels/vid_000332_frame0000103_jpg.rf.7cce5d9d1f78f69acab54a30cd41b86d.txt
#  extracting: valid/labels/vid_000332_frame0000109_jpg.rf.0f496c2a693156d2489f6514ca0fd4b5.txt
#  extracting: valid/labels/vid_000332_frame0000110_jpg.rf.3bb4b64c0329f1144a6025e8b090b9d0.txt
#  extracting: valid/labels/vid_000332_frame0000112_jpg.rf.01fac7d01c267805ac4e8764f1809391.txt
#  extracting: valid/labels/vid_000332_frame0000113_jpg.rf.41e9ad5f23df9d9f63e99297e5e9f843.txt
#  extracting: valid/labels/vid_000332_frame0000114_jpg.rf.89c35d9c7db645c5a14dbecc7b3910be.txt
#  extracting: valid/labels/vid_000332_frame0000115_jpg.rf.0bcae579e0bec0f1dbe410e1757b25f1.txt
#  extracting: valid/labels/vid_000332_frame0000116_jpg.rf.d00e8e9b44027ee846cc23fa451813cb.txt
#  extracting: valid/labels/vid_000332_frame0000117_jpg.rf.b5eff129b7f542a58d6a020a4b269d66.txt
#  extracting: valid/labels/vid_000334_frame0000001_jpg.rf.e8ed9470a7a5c62a8e7da1325609c837.txt
#  extracting: valid/labels/vid_000334_frame0000003_jpg.rf.7e80d44f2c7b5620567d6291ce473b77.txt
#  extracting: valid/labels/vid_000334_frame0000004_jpg.rf.1438487c652cbc41768cb30eed778bd3.txt
#  extracting: valid/labels/vid_000334_frame0000007_jpg.rf.9163198ee5e9d12fb98d47521feb2747.txt
#  extracting: valid/labels/vid_000334_frame0000008_jpg.rf.f0671c1f0819753069c349486491089f.txt
#  extracting: valid/labels/vid_000334_frame0000009_jpg.rf.db6f9069ebfee11827f45ec672d0d8a1.txt
#  extracting: valid/labels/vid_000334_frame0000010_jpg.rf.3709f836e68617392ef38d61cc141784.txt
#  extracting: valid/labels/vid_000334_frame0000011_jpg.rf.50d74845719c30daf57041c3bc419fc4.txt
#  extracting: valid/labels/vid_000334_frame0000012_jpg.rf.408db19989d3d22ff22b9ae30ab8382e.txt
#  extracting: valid/labels/vid_000334_frame0000013_jpg.rf.5c863d3c59d2d269550c7153058bfd34.txt
#  extracting: valid/labels/vid_000334_frame0000014_jpg.rf.da637bc846f1e35f8d9e9fc38412cc73.txt
#  extracting: valid/labels/vid_000334_frame0000015_jpg.rf.0426c55f860b20b06ce3028dcb10df66.txt
#  extracting: valid/labels/vid_000334_frame0000016_jpg.rf.52bde81335e4cee0d5bff3ce3c47fadb.txt
#  extracting: valid/labels/vid_000334_frame0000017_jpg.rf.784ee41755a1c20a35fa65d088f5e57a.txt
#  extracting: valid/labels/vid_000338_frame0000001_jpg.rf.0e482f34206453875f6062c1ea751176.txt
#  extracting: valid/labels/vid_000338_frame0000002_jpg.rf.c78a05157a44390b7df993485dba5f6f.txt
#  extracting: valid/labels/vid_000338_frame0000003_jpg.rf.ec343b4410510ad577f40b6809ceb780.txt
#  extracting: valid/labels/vid_000338_frame0000004_jpg.rf.eac9f1d74c1a5a6a647054208743c937.txt
#  extracting: valid/labels/vid_000338_frame0000005_jpg.rf.99a80a09e0bd89ffab42265b1416104d.txt
#  extracting: valid/labels/vid_000338_frame0000006_jpg.rf.63223c3ca60d62625fa4164853137b36.txt
#  extracting: valid/labels/vid_000338_frame0000007_jpg.rf.2194767d6c6e80d261a2d6940e65de04.txt
#  extracting: valid/labels/vid_000338_frame0000008_jpg.rf.c071c5c05c21c5b057b00c0682e9b33d.txt
#  extracting: valid/labels/vid_000338_frame0000009_jpg.rf.c26952b40fd785ccfe21a8bf865ee9f5.txt
#  extracting: valid/labels/vid_000338_frame0000010_jpg.rf.45ebd05be7604de1e2fa79aa5dbec602.txt
#  extracting: valid/labels/vid_000338_frame0000011_jpg.rf.447e144835eaacd18bc9353a956f02c8.txt
#  extracting: valid/labels/vid_000338_frame0000012_jpg.rf.e686d427abc96bed8425aca194b6719c.txt
#  extracting: valid/labels/vid_000338_frame0000013_jpg.rf.70e56cf6207ae47d1bcdf34e0ac7ff81.txt
#  extracting: valid/labels/vid_000338_frame0000015_jpg.rf.b3aab68256698f808559d947660cc44a.txt
#  extracting: valid/labels/vid_000338_frame0000016_jpg.rf.1b738581269c4b620aad6c2a36f8fac0.txt
#  extracting: valid/labels/vid_000338_frame0000017_jpg.rf.7554e279c7e19a19a936a24d4394c740.txt
#  extracting: valid/labels/vid_000338_frame0000018_jpg.rf.57a3c7687c2658f7cbbb766f0f819534.txt
#  extracting: valid/labels/vid_000338_frame0000019_jpg.rf.61b6b53dd1cd8a89f1f84c3712b3435d.txt
#  extracting: valid/labels/vid_000338_frame0000020_jpg.rf.3ea1b221bd590bcff92f24781b07d92e.txt
#  extracting: valid/labels/vid_000338_frame0000022_jpg.rf.2483a24c97294a5ff10132a3569b3a53.txt
#  extracting: valid/labels/vid_000338_frame0000023_jpg.rf.b04dc9c385f67d9a8cde01eb2f5c906c.txt
#  extracting: valid/labels/vid_000338_frame0000024_jpg.rf.9df6ab54788c191487e799a1ae0b193c.txt
#  extracting: valid/labels/vid_000338_frame0000026_jpg.rf.7595ba33516a3acca4a02be6ec8f09aa.txt
#  extracting: valid/labels/vid_000338_frame0000027_jpg.rf.5137dcc24e23c3e80117407767c87613.txt
#  extracting: valid/labels/vid_000339_frame0000001_jpg.rf.5aa3bda8cf54b04a363df0c6f9601127.txt
#  extracting: valid/labels/vid_000339_frame0000002_jpg.rf.e11d73068b2a5e549694c71ccd0c4118.txt
#  extracting: valid/labels/vid_000339_frame0000003_jpg.rf.38aa678cc059c0ae9a7ebf5b1f5e303e.txt
#  extracting: valid/labels/vid_000339_frame0000004_jpg.rf.1acb2ccc00c3877f9e8825e383c00d59.txt
#  extracting: valid/labels/vid_000339_frame0000005_jpg.rf.6178ec00e2fc65a59e31a86dbbb0af5a.txt
#  extracting: valid/labels/vid_000339_frame0000006_jpg.rf.5919974bc9782e2fa575ae1f6b188cd9.txt
#  extracting: valid/labels/vid_000339_frame0000007_jpg.rf.a49fa412e953778f7d1e0ed58a8d77f0.txt
#  extracting: valid/labels/vid_000339_frame0000008_jpg.rf.d67026c5b58751666ca0d310efffce1b.txt
#  extracting: valid/labels/vid_000339_frame0000010_jpg.rf.2ddd193a3ed9583b9785007f15abc370.txt
#  extracting: valid/labels/vid_000339_frame0000011_jpg.rf.47bfb1f5f128df9d4e6ad1bff564b82f.txt
#  extracting: valid/labels/vid_000339_frame0000012_jpg.rf.61f36010ec71b139a17b8f226e9e2f5c.txt
#  extracting: valid/labels/vid_000339_frame0000013_jpg.rf.599c43af215463f3a5693cfa9e03aa7f.txt
#  extracting: valid/labels/vid_000339_frame0000015_jpg.rf.e2694e4fe64563c660db33da759b88ee.txt
#  extracting: valid/labels/vid_000339_frame0000016_jpg.rf.b6288793d667a6619d4a41e430a1bb77.txt
#  extracting: valid/labels/vid_000339_frame0000018_jpg.rf.7fad3d9174592e41213ab8ee6a83f779.txt
#  extracting: valid/labels/vid_000339_frame0000019_jpg.rf.de09d43935b7a461af957590422f2ed1.txt
#  extracting: valid/labels/vid_000340_frame0000017_jpg.rf.6e65ecf250b26eb6fd9e7ddc668b6f9d.txt
#  extracting: valid/labels/vid_000340_frame0000018_jpg.rf.d27b58cb74adb5a189dd66f686ebd53b.txt
#  extracting: valid/labels/vid_000340_frame0000019_jpg.rf.e54f4c8549d26bc240a92fa48b756e02.txt
#  extracting: valid/labels/vid_000340_frame0000021_jpg.rf.f76a99cb65a86306f05d86ed52a46f22.txt
#  extracting: valid/labels/vid_000344_frame0000024_jpg.rf.b1d1cf60f932555af30eeb31a1912721.txt
#  extracting: valid/labels/vid_000344_frame0000027_jpg.rf.30a5da7de01f335d28e38b23e786104e.txt
#  extracting: valid/labels/vid_000344_frame0000031_jpg.rf.5f674d95a8c0fecd0546dac74550b2d6.txt
#  extracting: valid/labels/vid_000344_frame0000032_jpg.rf.07a79a8ecfe619a5d20b82b4397420cd.txt
#  extracting: valid/labels/vid_000344_frame0000033_jpg.rf.7ab8161aeeb85d9747ff598f4a62f601.txt
#  extracting: valid/labels/vid_000344_frame0000034_jpg.rf.260661b7af128abf666f9f4a91c546eb.txt
#  extracting: valid/labels/vid_000346_frame0000027_jpg.rf.0a217f75ba82706424053c62a241286b.txt
#  extracting: valid/labels/vid_000346_frame0000032_jpg.rf.10ce6d823b5c505b10cf23822b78c484.txt
#  extracting: valid/labels/vid_000346_frame0000036_jpg.rf.9ed3fb6b26cf690ab13c073d25d3aa97.txt
#  extracting: valid/labels/vid_000346_frame0000037_jpg.rf.aa361458327710d379eae154ae13e02f.txt
#  extracting: valid/labels/vid_000346_frame0000044_jpg.rf.fc380b26a9c6a0416b9174b8fbc5c65b.txt
#  extracting: valid/labels/vid_000346_frame0000045_jpg.rf.21eecfe8fd76d258fa5dc08bb02af950.txt
#  extracting: valid/labels/vid_000532_frame0000047_jpg.rf.88a1016a729fb1c125fce64f1d42a4ed.txt
#  extracting: valid/labels/vid_000532_frame0000049_jpg.rf.187de74e4548634d6067f0c55acaf3c2.txt
#  extracting: valid/labels/vid_000532_frame0000050_jpg.rf.fc0e65eee8d40882fd6d847222c3dcb8.txt
#  extracting: valid/labels/vid_000532_frame0000053_jpg.rf.11c676e70315bfa32b67b0eb6ccb3dde.txt
#  extracting: valid/labels/vid_000532_frame0000054_jpg.rf.36ee7d0911c359ce64371c28691ae189.txt
#  extracting: valid/labels/vid_000532_frame0000055_jpg.rf.b3233825b7f48a06bc2884c0e8f82323.txt
#  extracting: valid/labels/vid_000532_frame0000060_jpg.rf.04f30f6a61bd4fc6215e3a023e66dab1.txt
#  extracting: valid/labels/vid_000532_frame0000072_jpg.rf.7d93a554cdf52ebd6da7b5921f1b30b6.txt
#  extracting: valid/labels/vid_000532_frame0000073_jpg.rf.08f6d45409a5e91db7387b5b78f34722.txt

# %%
# confirm unzip worked as expected and output annotation data from the .yaml file
# %cat data.yaml
# Out:
# cat: data.yaml: No such file or directory

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in c:\users\legion\jp_notebook\robotarm1\lib\site-packages (5.4.1)

# %%
# define number of classes based on YAML
import yaml
with open("data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27248/812712610.py in <module>
#       1 # define number of classes based on YAML
#       2 import yaml
# ----> 3 with open("data.yaml", 'r') as stream:
#       4     num_classes = str(yaml.safe_load(stream)['nc'])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.yaml'

# %%
#this is the model configuration we will use for our project. Smallest and fastest.
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# UsageError: Line magic function `%cat` not found.

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
# This is a hack to keep Google Colab from kicking you out. Paste this in the console when you start training. This will click a button with an Id on this page and therefore you won't be considered Idle.

# P.S do not close the console.
``` 
function ClickConnect(){
console.log("Working"); 
document
  .querySelector('#top-toolbar > colab-connect-button')
  .shadowRoot.querySelector('#connect')
  .click() 
}
setInterval(ClickConnect,60000)
```
# Out:
#   File "<ipython-input-10-3dc5fee55052>", line 4
#     ```
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 50 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 10 --data '../data.yaml' --cfg ./models/custom_yolov5s.yaml --weights /path/to/weights --name name --cache
# Out:
# /content/yolov5
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v4.0-189-gc03d590 torch 1.8.1+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='./models/custom_yolov5s.yaml', data='../data.yaml', device='', entity=None, epochs=10, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='uw-2', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/uw-22', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='/mydrive/OceanPlastic/yolo-v5/weights/90Percent/weights/best.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2021-04-08 23:31:46.349140: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7255094 parameters, 7255094 gradients, 16.8 GFLOPS
#
# Transferred 368/370 items from /mydrive/OceanPlastic/yolo-v5/weights/90Percent/weights/best.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# /mydrive/OceanPlastic/yolo-v5/weights/90Percent/weights/best.pt has been trained for 1080 epochs. Fine-tuning for 10 additional epochs.
# train: Scanning '../train/labels' images and labels... 1886 found, 0 missing, 0 empty, 0 corrupted: 100% 1886/1886 [00:00<00:00, 3474.23it/s]
# train: New cache created: ../train/labels.cache
# train: Caching images (1.0GB): 100% 1886/1886 [00:03<00:00, 577.41it/s]
# val: Scanning '../valid/labels.cache' images and labels... 624 found, 0 missing, 0 empty, 0 corrupted: 100% 624/624 [00:00<00:00, 3624994.04it/s]
# val: Caching images (0.3GB): 100% 624/624 [00:01<00:00, 457.81it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 4.87, Best Possible Recall (BPR) = 0.9986
# Image sizes 416 train, 416 test
# Using 2 dataloader workers
# Logging results to runs/train/uw-22
# Starting training for 1090 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#  1081/1089     1.93G   0.03049   0.01393         0   0.04442        42       416: 100% 118/118 [00:17<00:00,  6.91it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:03<00:00,  5.68it/s]
#                  all         624         857       0.932       0.884       0.918       0.638
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#  1082/1089     1.52G   0.03233   0.01612         0   0.04845        29       416:  14% 16/118 [00:02<00:13,  7.51it/s]Traceback (most recent call last):
#   File "train.py", line 543, in <module>
#     train(hyp, opt, device, tb_writer)
#   File "train.py", line 303, in train
#     pred = model(imgs)  # forward
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/yolov5/models/yolo.py", line 123, in forward
#     return self.forward_once(x, profile)  # single-scale inference, train
#   File "/content/yolov5/models/yolo.py", line 139, in forward_once
#     x = m(x)  # run
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/yolov5/models/common.py", line 121, in forward
#     y2 = self.cv2(x)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
# KeyboardInterrupt
#  1082/1089     1.52G   0.03233   0.01612         0   0.04845        29       416:  14% 16/118 [00:02<00:16,  6.26it/s]
# CPU times: user 439 ms, sys: 49.9 ms, total: 489 ms
# Wall time: 39.7 s

# %%
# %cd /content/yolov5/
# !python test.py --data '../data.yaml' --img 416 --conf 0.40  --weights /path/to/weights
# Out:
# /content/yolov5
# Namespace(augment=False, batch_size=32, conf_thres=0.4, data='../data.yaml', device='', exist_ok=False, img_size=416, iou_thres=0.6, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/mydrive/OceanPlastic/yolo-v5/weights/90Percent/weights/best.pt'])
# YOLOv5 🚀 v4.0-189-gc03d590 torch 1.8.1+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients, 16.8 GFLOPS
# val: Scanning '../valid/labels' images and labels... 276 found, 0 missing, 24 empty, 0 corrupted: 100% 276/276 [00:00<00:00, 3702.18it/s]
# val: New cache created: ../valid/labels.cache
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 9/9 [00:02<00:00,  3.29it/s]
# the true positive and false positive values are 273 12
#                  all         276         274       0.971       0.993       0.987       0.863
# Speed: 2.3/1.4/3.7 ms inference/NMS/total per 416x416 image at batch-size 32
# Results saved to runs/test/exp21

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... #
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights /path/to/weights --img 416 --source /path/to/images --conf 0.50
# Out:
# [Errno 2] No such file or directory: '/content/yolov5/'
# /content
# python3: can't open file 'detect.py': [Errno 2] No such file or directory

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
